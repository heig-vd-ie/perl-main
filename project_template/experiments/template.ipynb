# %% [markdown]
# # TEMPLATE

# %%
import src.template_test as template_test

# %% [markdown]
# ---
# ##  Configuration

# %%
template_test.print_hello(3)
# Out:
# Hello, World!
# Hello, World!
# Hello, World!
